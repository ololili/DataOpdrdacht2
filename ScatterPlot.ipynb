# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import import_ipynb
from DataPreparation import get_small_df, refine_df, mergedPopulationCounts
# Out:
# importing Jupyter notebook from DataPreparation.ipynb

# %%
df = pd.read_csv("US_Accidents_June20.csv")
#df = get_small_df(300000)
df = refine_df(df)

# %%
df_merged = mergedPopulationCounts(df)
df_merged = df_merged.set_index('City + State')

# %%
sns.set(rc={"figure.figsize":(10,10)})
sns.regplot(x="Population", y="Counts per 100K", 
                    data=df_merged,
                    scatter_kws={'alpha':0.5},
                    fit_reg=False)

plt.xscale("log")
plt.yscale("log")
plt.title("Number of accidents per capita against population for cities")
plt.xlabel("Population")
plt.ylabel("Accidents per 100k citizens")
plt.savefig("AccidentsAgainstPopulation.png",dpi=210)
plt.show()
