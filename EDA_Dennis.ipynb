# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.patches as mpatches
# %matplotlib inline
import seaborn as sns
import calendar
import plotly as pt
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from pylab import *
import matplotlib.patheffects as PathEffects

# %%
import descartes
import geopandas as gpd
from Levenshtein import distance
from itertools import product
from fuzzywuzzy import fuzz
from fuzzywuzzy import process
from scipy.spatial.distance import pdist, squareform
from shapely.geometry import Point, Polygon

import geoplot
import geopy

# %%
df = pd.read_csv("DataSubsetRaw.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         ID    Source    TMC  Severity           Start_Time  \
# 0      956661   A-956687  MapQuest  201.0         2  2019-09-03 16:02:01
# 1     2857880  A-2857996      Bing    NaN         1  2020-03-18 16:15:54
# 2       67872    A-67874  MapQuest  201.0         2  2016-10-31 06:46:34
# 3      181500   A-181502  MapQuest  406.0         3  2016-12-25 01:22:48
# 4     3292758  A-3292918      Bing    NaN         2  2018-07-02 14:35:28
#
#               End_Time  Start_Lat   Start_Lng   End_Lat  ...  Roundabout  \
# 0  2019-09-03 16:46:48  30.420919  -91.187523       NaN  ...       False
# 1  2020-03-18 16:30:54  41.357090  -81.904190  41.33235  ...       False
# 2  2016-10-31 07:24:00  33.695847 -117.863785       NaN  ...       False
# 3  2016-12-25 01:52:15  42.378181  -83.062767       NaN  ...       False
# 4  2018-07-02 20:35:28  39.173220  -77.245400  39.17589  ...       False
#
#    Station   Stop  Traffic_Calming Traffic_Signal Turning_Loop Sunrise_Sunset  \
# 0    False  False            False          False        False            Day
# 1    False  False            False          False        False            Day
# 2    False  False            False          False        False          Night
# 3    False  False            False          False        False          Night
# 4    False  False            False          False        False            Day
#
#   Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day               Day                   Day
# 1            Day               Day                   Day
# 2            Day               Day                   Day
# 3          Night             Night                 Night
# 4            Day               Day                   Day
#
# [5 rows x 50 columns]
